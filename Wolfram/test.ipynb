# %%
f[x_]:=a x (1-x)

# %%
f[2]
# Out:
# -2 a

# %%
NestList[f,x,5]
# Out:
#                   2
# {x, a (1 - x) x, a  (1 - x) x (1 - a (1 - x) x),
#
#      3                                   2
# >   a  (1 - x) x (1 - a (1 - x) x) (1 - a  (1 - x) x (1 - a (1 - x) x)),
#
#      4                                   2
# >   a  (1 - x) x (1 - a (1 - x) x) (1 - a  (1 - x) x (1 - a (1 - x) x))
#
#            3                                   2
# >    (1 - a  (1 - x) x (1 - a (1 - x) x) (1 - a  (1 - x) x (1 - a (1 - x) x))),
#
#      5                                   2
# >   a  (1 - x) x (1 - a (1 - x) x) (1 - a  (1 - x) x (1 - a (1 - x) x))
#
#            3                                   2
# >    (1 - a  (1 - x) x (1 - a (1 - x) x) (1 - a  (1 - x) x (1 - a (1 - x) x)))
#
#            4                                   2
# >    (1 - a  (1 - x) x (1 - a (1 - x) x) (1 - a  (1 - x) x (1 - a (1 - x) x))
#
#               3                                   2
# >       (1 - a  (1 - x) x (1 - a (1 - x) x) (1 - a  (1 - x) x (1 - a (1 - x) x))))}

# %%
a=1;
f[0.1]
# Out:
# 0.09

# %%
NestList[f,0.1,15]
# Out:
# {0.1, 0.09, 0.0819, 0.0751924, 0.0695385, 0.0647029, 0.0605164, 0.0568542, 0.0536218,
#
# >   0.0507465, 0.0481713, 0.0458508, 0.0437485, 0.0418346, 0.0400845, 0.0384777}

# %%
Manipulate[a=s;
ListLinePlot[NestList[f,0.1,15],Mesh->All,PlotRange->{0.1}],{s,1,2}]
# Out:
# Manipulate[a = s; ListLinePlot[NestList[f, 0.1, 15], Mesh -> All, PlotRange -> {0.1}],
#
# >   {s, 1, 2}]

# %%
Graphics3D[Tube[{{0,0,0},{1,1,1}}]]
# Out:
# -Graphics3D-

# %%
$Version
# Out:
# 12.0.1 for Linux x86 (64-bit) (October 16, 2019)

# %%
Plot3D[Sin[x y],{x,-Pi,Pi},{y,-Pi,Pi}]
